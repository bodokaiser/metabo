# %%
import numpy as np
import scipy as sp
import nmrglue as ng

# %%
from matplotlib import pyplot as plt

acetone = ng.varian.read('HMDB01659-1H')

fig, axes = plt.subplots(2, sharex=True, figsize=(12, 12))

axes[0].plot(acetone[1])
axes[1].plot(sp.fft(acetone[1]))

plt.show()

# %%
methyl = ng.varian.read('HMDB00699-1H')

fig, axes = plt.subplots(2, sharex=True, figsize=(12, 12))

axes[0].plot(methyl[1])
axes[1].plot(sp.fft(methyl[1]))

plt.show()

# %%
hydroxi = ng.bruker.read('HMDB00754-1H')

fig, axes = plt.subplots(2, sharex=True, figsize=(12, 12))

axes[0].plot(hydroxi[1])
axes[1].plot(sp.fft(hydroxi[1]))

plt.show()
